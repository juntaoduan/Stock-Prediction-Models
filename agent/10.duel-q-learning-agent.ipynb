# %%
import numpy as np
import pandas as pd
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# Out:
# WARNING:tensorflow:From c:\users\juntao\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\compat\v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
df = pd.read_csv('../dataset/GOOG-year.csv')
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2016-11-02  778.200012  781.650024  763.450012  768.700012  768.700012
# 1  2016-11-03  767.250000  769.950012  759.030029  762.130005  762.130005
# 2  2016-11-04  750.659973  770.359985  750.560974  762.020020  762.020020
# 3  2016-11-07  774.500000  785.190002  772.549988  782.520020  782.520020
# 4  2016-11-08  783.400024  795.632996  780.190002  790.510010  790.510010
#
#     Volume
# 0  1872400
# 1  1943200
# 2  2134800
# 3  1585100
# 4  1350800

# %%
from collections import deque
import random


class Agent:
    def __init__(self, state_size, window_size, trend, skip, batch_size):
        self.state_size = state_size
        self.window_size = window_size
        self.half_window = window_size // 2
        self.trend = trend
        self.skip = skip
        self.action_size = 3
        self.batch_size = batch_size
        self.memory = deque(maxlen = 1000)
        self.inventory = []

        self.gamma = 0.95
        self.epsilon = 0.5
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.999

        tf.reset_default_graph()
        self.sess = tf.InteractiveSession()
        self.X = tf.placeholder(tf.float32, [None, self.state_size])
        self.Y = tf.placeholder(tf.float32, [None, self.action_size])
        feed = tf.layers.dense(self.X, 512, activation = tf.nn.relu)
        tensor_action, tensor_validation = tf.split(feed,2,1)
        feed_action = tf.layers.dense(tensor_action, self.action_size)
        feed_validation = tf.layers.dense(tensor_validation, 1)
        self.logits = feed_validation + tf.subtract(feed_action,tf.reduce_mean(feed_action,axis=1,keep_dims=True))
        self.cost = tf.reduce_mean(tf.square(self.Y - self.logits))
        self.optimizer = tf.train.GradientDescentOptimizer(1e-5).minimize(
            self.cost
        )
        self.sess.run(tf.global_variables_initializer())

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)
        return np.argmax(
            self.sess.run(self.logits, feed_dict = {self.X: state})[0]
        )
    
    def get_state(self, t):
        window_size = self.window_size + 1
        d = t - window_size + 1
        block = self.trend[d : t + 1] if d >= 0 else -d * [self.trend[0]] + self.trend[0 : t + 1]
        res = []
        for i in range(window_size - 1):
            res.append(block[i + 1] - block[i])
        return np.array([res])

    def replay(self, batch_size):
        mini_batch = []
        l = len(self.memory)
        for i in range(l - batch_size, l):
            mini_batch.append(self.memory[i])
        replay_size = len(mini_batch)
        X = np.empty((replay_size, self.state_size))
        Y = np.empty((replay_size, self.action_size))
        states = np.array([a[0][0] for a in mini_batch])
        new_states = np.array([a[3][0] for a in mini_batch])
        Q = self.sess.run(self.logits, feed_dict = {self.X: states})
        Q_new = self.sess.run(self.logits, feed_dict = {self.X: new_states})
        for i in range(len(mini_batch)):
            state, action, reward, next_state, done = mini_batch[i]
            target = Q[i]
            target[action] = reward
            if not done:
                target[action] += self.gamma * np.amax(Q_new[i])
            X[i] = state
            Y[i] = target
        cost, _ = self.sess.run(
            [self.cost, self.optimizer], feed_dict = {self.X: X, self.Y: Y}
        )
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        return cost
    
    def buy(self, initial_money):
        starting_money = initial_money
        states_sell = []
        states_buy = []
        inventory = []
        state = self.get_state(0)
        for t in range(0, len(self.trend) - 1, self.skip):
            action = self.act(state)
            next_state = self.get_state(t + 1)
            
            if action == 1 and initial_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                inventory.append(self.trend[t])
                initial_money -= self.trend[t]
                states_buy.append(t)
                print('day %d: buy 1 unit at price %f, total balance %f'% (t, self.trend[t], initial_money))
                
                
            elif action == 2 and len(inventory):
                bought_price = inventory.pop(0)
                initial_money += self.trend[t]
                states_sell.append(t)
                try:
                    invest = ((close[t] - bought_price) / bought_price) * 100
                except:
                    invest = 0
                print(
                    'day %d, sell 1 unit at price %f, investment %f %%, total balance %f,'
                    % (t, close[t], invest, initial_money)
                )
            
            state = next_state
        invest = ((initial_money - starting_money) / starting_money) * 100
        total_gains = initial_money - starting_money
        return states_buy, states_sell, total_gains, invest
        
    def train(self, iterations, checkpoint, initial_money):
        for i in range(iterations):
            total_profit = 0
            inventory = []
            state = self.get_state(0)
            starting_money = initial_money
            for t in range(0, len(self.trend) - 1, self.skip):
                action = self.act(state)
                next_state = self.get_state(t + 1)
                
                if action == 1 and starting_money >= self.trend[t] and t < (len(self.trend) - self.half_window):
                    inventory.append(self.trend[t])
                    starting_money -= self.trend[t]
                
                elif action == 2 and len(inventory) > 0:
                    bought_price = inventory.pop(0)
                    total_profit += self.trend[t] - bought_price
                    starting_money += self.trend[t]
                    
                invest = ((starting_money - initial_money) / initial_money)
                self.memory.append((state, action, invest, 
                                    next_state, starting_money < initial_money))
                state = next_state
                batch_size = min(self.batch_size, len(self.memory))
                cost = self.replay(batch_size)
            if (i+1) % checkpoint == 0:
                print('epoch: %d, total rewards: %f.3, cost: %f, total money: %f'%(i + 1, total_profit, cost,
                                                                                  starting_money))

# %%
close = df.Close.values.tolist()
initial_money = 10000
window_size = 30
skip = 1
batch_size = 32
agent = Agent(state_size = window_size, 
              window_size = window_size, 
              trend = close, 
              skip = skip, 
              batch_size = batch_size)
agent.train(iterations = 200, checkpoint = 10, initial_money = initial_money)
# Out:
# c:\users\juntao\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\keras\legacy_tf_layers\core.py:171: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   warnings.warn('`tf.layers.dense` is deprecated and '
# c:\users\juntao\appdata\local\programs\python\python39\lib\site-packages\tensorflow\python\keras\engine\base_layer_v1.py:1692: UserWarning: `layer.apply` is deprecated and will be removed in a future version. Please use `layer.__call__` method instead.
#   warnings.warn('`layer.apply` is deprecated and '
# epoch: 10, total rewards: 201.504823.3, cost: 1.191779, total money: 10201.504823
# epoch: 20, total rewards: 288.994689.3, cost: 0.596340, total money: 10288.994689
# epoch: 30, total rewards: 155.404723.3, cost: 0.360575, total money: 10155.404723
# epoch: 40, total rewards: 189.264709.3, cost: 0.371170, total money: 10189.264709
# epoch: 50, total rewards: 202.014708.3, cost: 0.272856, total money: 10202.014708
# epoch: 60, total rewards: 263.104735.3, cost: 0.165877, total money: 10263.104735
# epoch: 70, total rewards: 184.224792.3, cost: 0.131883, total money: 10184.224792
# epoch: 80, total rewards: 69.774779.3, cost: 0.105125, total money: 10069.774779
# epoch: 90, total rewards: 120.644775.3, cost: 0.085134, total money: 10120.644775
# epoch: 100, total rewards: 207.574705.3, cost: 0.073285, total money: 10207.574705
# epoch: 110, total rewards: 157.894773.3, cost: 0.061706, total money: 10157.894773
# epoch: 120, total rewards: 155.454834.3, cost: 0.051224, total money: 10155.454834
# epoch: 130, total rewards: 151.954772.3, cost: 0.045126, total money: 10151.954772
# epoch: 140, total rewards: 160.774780.3, cost: 0.038593, total money: 10160.774780
# epoch: 150, total rewards: 47.684816.3, cost: 0.033748, total money: 10047.684816
# epoch: 160, total rewards: 102.504822.3, cost: 0.029614, total money: 10102.504822
# epoch: 170, total rewards: 71.024780.3, cost: 0.026421, total money: 10071.024780
# epoch: 180, total rewards: 208.084778.3, cost: 0.024204, total money: 10208.084778
# epoch: 190, total rewards: 119.364806.3, cost: 0.026060, total money: 10119.364806
# epoch: 200, total rewards: 102.114747.3, cost: 0.031444, total money: 10102.114747

# %%
states_buy, states_sell, total_gains, invest = agent.buy(initial_money = initial_money)
# Out:
# day 3: buy 1 unit at price 782.520020, total balance 9217.479980
# day 5, sell 1 unit at price 785.309998, investment 0.356538 %, total balance 10002.789978,
# day 9: buy 1 unit at price 758.489990, total balance 9244.299988
# day 11, sell 1 unit at price 771.229980, investment 1.679652 %, total balance 10015.529968,
# day 13: buy 1 unit at price 769.200012, total balance 9246.329956
# day 14, sell 1 unit at price 768.270020, investment -0.120904 %, total balance 10014.599976,
# day 22: buy 1 unit at price 762.520020, total balance 9252.079956
# day 24, sell 1 unit at price 771.190002, investment 1.137017 %, total balance 10023.269958,
# day 26: buy 1 unit at price 789.289978, total balance 9233.979980
# day 27, sell 1 unit at price 789.270020, investment -0.002529 %, total balance 10023.250000,
# day 30: buy 1 unit at price 797.849976, total balance 9225.400024
# day 31: buy 1 unit at price 790.799988, total balance 8434.600036
# day 32, sell 1 unit at price 794.200012, investment -0.457475 %, total balance 9228.800048,
# day 33: buy 1 unit at price 796.419983, total balance 8432.380065
# day 34, sell 1 unit at price 794.559998, investment 0.475469 %, total balance 9226.940063,
# day 36, sell 1 unit at price 789.909973, investment -0.817409 %, total balance 10016.850036,
# day 37: buy 1 unit at price 791.549988, total balance 9225.300048
# day 40, sell 1 unit at price 771.820007, investment -2.492575 %, total balance 9997.120055,
# day 41: buy 1 unit at price 786.140015, total balance 9210.980040
# day 43: buy 1 unit at price 794.020020, total balance 8416.960020
# day 46, sell 1 unit at price 804.789978, investment 2.372346 %, total balance 9221.749998,
# day 47, sell 1 unit at price 807.909973, investment 1.749320 %, total balance 10029.659971,
# day 52: buy 1 unit at price 802.174988, total balance 9227.484983
# day 60: buy 1 unit at price 796.789978, total balance 8430.695005
# day 64: buy 1 unit at price 801.340027, total balance 7629.354978
# day 66, sell 1 unit at price 808.380005, investment 0.773524 %, total balance 8437.734983,
# day 67, sell 1 unit at price 809.559998, investment 1.602683 %, total balance 9247.294981,
# day 69: buy 1 unit at price 819.239990, total balance 8428.054991
# day 70, sell 1 unit at price 820.450012, investment 2.384754 %, total balance 9248.505003,
# day 71, sell 1 unit at price 818.979980, investment -0.031738 %, total balance 10067.484983,
# day 73: buy 1 unit at price 828.070007, total balance 9239.414976
# day 75: buy 1 unit at price 830.760010, total balance 8408.654966
# day 76: buy 1 unit at price 831.330017, total balance 7577.324949
# day 77, sell 1 unit at price 828.640015, investment 0.068836 %, total balance 8405.964964,
# day 85, sell 1 unit at price 835.369995, investment 0.554912 %, total balance 9241.334959,
# day 87, sell 1 unit at price 843.250000, investment 1.433845 %, total balance 10084.584959,
# day 89: buy 1 unit at price 845.619995, total balance 9238.964964
# day 90, sell 1 unit at price 847.200012, investment 0.186847 %, total balance 10086.164976,
# day 91: buy 1 unit at price 848.780029, total balance 9237.384947
# day 93: buy 1 unit at price 848.400024, total balance 8388.984923
# day 95, sell 1 unit at price 829.590027, investment -2.260892 %, total balance 9218.574950,
# day 96, sell 1 unit at price 817.580017, investment -3.632721 %, total balance 10036.154967,
# day 99: buy 1 unit at price 820.919983, total balance 9215.234984
# day 103, sell 1 unit at price 838.549988, investment 2.147591 %, total balance 10053.784972,
# day 104: buy 1 unit at price 834.570007, total balance 9219.214965
# day 105, sell 1 unit at price 831.409973, investment -0.378642 %, total balance 10050.624938,
# day 106: buy 1 unit at price 827.880005, total balance 9222.744933
# day 107, sell 1 unit at price 824.669983, investment -0.387740 %, total balance 10047.414916,
# day 112: buy 1 unit at price 837.169983, total balance 9210.244933
# day 113: buy 1 unit at price 836.820007, total balance 8373.424926
# day 116: buy 1 unit at price 843.190002, total balance 7530.234924
# day 119, sell 1 unit at price 871.729980, investment 4.128194 %, total balance 8401.964904,
# day 121: buy 1 unit at price 905.960022, total balance 7496.004882
# day 122, sell 1 unit at price 912.570007, investment 9.052126 %, total balance 8408.574889,
# day 123, sell 1 unit at price 916.440002, investment 8.687247 %, total balance 9325.014891,
# day 125, sell 1 unit at price 931.659973, investment 2.836764 %, total balance 10256.674864,
# day 137: buy 1 unit at price 941.859985, total balance 9314.814879
# day 140: buy 1 unit at price 969.539978, total balance 8345.274901
# day 142: buy 1 unit at price 975.880005, total balance 7369.394896
# day 143, sell 1 unit at price 964.859985, investment 2.441977 %, total balance 8334.254881,
# day 145, sell 1 unit at price 975.599976, investment 0.625038 %, total balance 9309.854857,
# day 151: buy 1 unit at price 942.900024, total balance 8366.954833
# day 154, sell 1 unit at price 942.309998, investment -3.439973 %, total balance 9309.264831,
# day 155: buy 1 unit at price 939.780029, total balance 8369.484802
# day 156, sell 1 unit at price 957.369995, investment 1.534624 %, total balance 9326.854797,
# day 158: buy 1 unit at price 959.450012, total balance 8367.404785
# day 159, sell 1 unit at price 957.090027, investment 1.841920 %, total balance 9324.494812,
# day 162, sell 1 unit at price 927.330017, investment -3.347751 %, total balance 10251.824829,
# day 165: buy 1 unit at price 908.729980, total balance 9343.094849
# day 167, sell 1 unit at price 911.710022, investment 0.327935 %, total balance 10254.804871,
# day 169: buy 1 unit at price 918.590027, total balance 9336.214844
# day 171, sell 1 unit at price 930.090027, investment 1.251919 %, total balance 10266.304871,
# day 172: buy 1 unit at price 943.830017, total balance 9322.474854
# day 174, sell 1 unit at price 955.989990, investment 1.288365 %, total balance 10278.464844,
# day 186: buy 1 unit at price 930.830017, total balance 9347.634827
# day 189: buy 1 unit at price 927.960022, total balance 8419.674805
# day 190, sell 1 unit at price 929.359985, investment -0.157927 %, total balance 9349.034790,
# day 192, sell 1 unit at price 922.900024, investment -0.545282 %, total balance 10271.934814,
# day 195: buy 1 unit at price 922.669983, total balance 9349.264831
# day 197, sell 1 unit at price 926.960022, investment 0.464959 %, total balance 10276.224853,
# day 201: buy 1 unit at price 924.690002, total balance 9351.534851
# day 206: buy 1 unit at price 921.289978, total balance 8430.244873
# day 207, sell 1 unit at price 929.570007, investment 0.527745 %, total balance 9359.814880,
# day 209, sell 1 unit at price 937.340027, investment 1.742128 %, total balance 10297.154907,
# day 210: buy 1 unit at price 928.450012, total balance 9368.704895
# day 212, sell 1 unit at price 935.950012, investment 0.807798 %, total balance 10304.654907,
# day 214: buy 1 unit at price 929.080017, total balance 9375.574890
# day 217, sell 1 unit at price 925.109985, investment -0.427308 %, total balance 10300.684875,
# day 221: buy 1 unit at price 931.580017, total balance 9369.104858
# day 223: buy 1 unit at price 928.530029, total balance 8440.574829
# day 224, sell 1 unit at price 920.969971, investment -1.138930 %, total balance 9361.544800,
# day 225, sell 1 unit at price 924.859985, investment -0.395253 %, total balance 10286.404785,
# day 227: buy 1 unit at price 949.500000, total balance 9336.904785
# day 228, sell 1 unit at price 959.109985, investment 1.012110 %, total balance 10296.014770,

# %%
fig = plt.figure(figsize = (15,5))
plt.plot(close, color='r', lw=2.)
plt.plot(close, '^', markersize=10, color='m', label = 'buying signal', markevery = states_buy)
plt.plot(close, 'v', markersize=10, color='k', label = 'selling signal', markevery = states_sell)
plt.title('total gains %f, total investment %f%%'%(total_gains, invest))
plt.legend()
plt.show()
